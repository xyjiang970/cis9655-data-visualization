# %%
# Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Miscellaneous Settings
pd.options.mode.chained_assignment = None  # default='warn'

# %%
dataset = "https://github.com/xyjiang970/cis9655-data-visualization/blob/main/project/Datasets/UN_DESA_migration.csv?raw=true"
migration_data = pd.read_csv(dataset)

# %%
migration_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16561 entries, 0 to 16560
# Data columns (total 43 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Year                                            16561 non-null  int64
#  1   Country                                         16561 non-null  object
#  2   Resettled by destination per capita             529 non-null    float64
#  3   Remittances (% GDP)                             7389 non-null   float64
#  4   Five-year change immigrants                     5517 non-null   float64
#  5   Refugees by destination                         5405 non-null   float64
#  6   Child migrants (UNICEF)                         244 non-null    float64
#  7   Resettled by origin                             2613 non-null   float64
#  8   Child migrants (under-20s)                      5995 non-null   float64
# ...

# %%
migration_data = migration_data.groupby("Year")

# %%
migration_data.head(5)
# Out:
#       Year                     Country  Resettled by destination per capita  \
# 0     1955   Central and Southern Asia                                  NaN
# 1     1960   Central and Southern Asia                                  NaN
# 2     1965   Central and Southern Asia                                  NaN
# 3     1970   Central and Southern Asia                                  NaN
# 4     1975   Central and Southern Asia                                  NaN
# ...    ...                         ...                                  ...
# 4773  1954                      France                                  NaN
# 4775  1956                      France                                  NaN
# 4776  1957                      France                                  NaN
# 4777  1958                      France                                  NaN
# 4778  1959                      France                                  NaN
#
# ...

# %%
migration_data.to_csv('result.csv', index=False)
# Out:
# ----------------------------------------------------------------------
# AttributeError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22380/4062099342.py in <module>
# ----> 1 migration_data.to_csv('result.csv', index=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     909             return self[attr]
#     910
# --> 911         raise AttributeError(
#     912             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     913         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'to_csv'
